# %%
import datetime
import os
import re
import time

import numpy as np
import pandas as pd
import urllib.request

from bs4 import BeautifulSoup

# %%
class BingHeadlineGetter:
    
    # delay in seconds for each http request sent
    LOWER_REQUEST_DELAY = 0.5
    UPPER_REQUEST_DELAY = 1.5
    
    # bing constant for the infinite scroller
    SCROLL_SIZE = 10
    
    SCROLL_INDEX_REGEX = re.compile(r'.*first=(\d+).*')
    
    # have the replaces so that we can get it all on one line
    SEARCH_URL = '''https://www.bing.com/news/infinitescrollajax?qs=n&form=NWRFSH&sp=-1&
        ghc=1&pq={term:s}&sc=8-6&sk=&cvid=FE95A940E6DD4103AD0FC2A09728BD5B&
        InfiniteScroll=1&q={term:s}&first=11&IG=B131BA2E33924919A80CAF9FBCB2EFB4&IID=NEWS.302&SFX=1&PCW=794'''\
        .replace('\n', '').replace('\t', '').replace(' ', '').format
  
    @classmethod
    def _get_delay(cls):
        return np.random.uniform(low=cls.LOWER_REQUEST_DELAY, high=cls.UPPER_REQUEST_DELAY)
    
    @classmethod
    def get_url(cls, search_term):
        return cls.SEARCH_URL(term=search_term.replace(' ', '+'))
    
    @staticmethod
    def _get_headlines(soup):
        headlines = list()
        divs = soup.findAll('a')
        
        for div in divs:
            if div.has_attr('class') and div['class'] == ['title']:
                headlines.append(div.text)
                
        return headlines
    
    @classmethod
    def get_headlines(cls, search_term, num_pages):
        assert num_pages > 0
        
        url = cls.get_url(search_term)
        scroll_index = int(re.match(cls.SCROLL_INDEX_REGEX, url).group(1))
        
        headlines = list()
        
        for _ in range(num_pages):
            with urllib.request.urlopen(url) as response:
                html = response.read()
                
            soup = BeautifulSoup(html, 'lxml')
            headlines.extend(cls._get_headlines(soup))
            
            url = url.replace('first={:d}'.format(scroll_index), 'first={:d}'.format(scroll_index + cls.SCROLL_SIZE))
            scroll_index += 1
        
            # let's try not to get noticed...
            time.sleep(cls._get_delay())
            
        return headlines

# %%
search_term = 'brexit'
num_pages = 200

headlines = BingHeadlineGetter.get_headlines(search_term, num_pages)

# %%
def store_headlines(headlines, filename):
    directory = 'C:/Users/daonw/Documents/SentimentAnalysisData'
    series = pd.Series(headlines)
    filename = '{:s}-{:%Y-%m-%d}.pkl'.format(filename, datetime.datetime.now())
    
    location = os.path.join(directory, filename)
    series.to_pickle(location)

# %%
store_headlines(headlines, 'brexit_headlines')

# %%
headlines
# Out:
# ["BOE governor is 'completely wrong' over no-deal Brexit warning, JD Wetherspoon CEO says",
#  "Anti-Brexit campaigner seeks to 'end the chaos'",
#  'Yellowhammer: the Brexit bird with a story to tell about the EU',
#  'EU Brexit negotiator reveals ‘divorce deal’ with Britain will go through in the next few weeks',
#  "Former British foreign secretary Boris Johnson condemned for Brexit 'suicide vest' comment",
#  "Brexit deal 'realistic within 6-8 weeks'",
#  'Brexit is a disaster and I would love to reverse it, says actress Celia Imrie',
#  'Brexit will strike a discordant note for Britain’s musical relationship with Europe',
#  'Tories ban anti-Brexit group Best For Britain from their party conference',
#  '2m Brits need to renew their passports immediately or risk being barred from Europe if we fail to get a Brexit d…',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'JPMorgan and Citi say just hundreds of jobs will leave London due to Brexit — not thousands',
#  'May must walk tall in the mountains and sell her Brexit plan to EU in Salzburg showdown',
#  'Brexit rebels in UK PM May’s party discuss ousting her',
#  'No-deal Brexit could see UK house prices plummet, bank governor warns',
#  'London Mayor Sadiq Khan demands another Brexit referendum',
#  'Riots, food and medicine shortages among concerns in the UK as Brexit deal deadline looms',
#  "'High priest of Project Fear': Mark Carney slammed over dire Brexit warnings",
#  'London mayor Sadiq Khan calls for second Brexit referendum',
#  'Brexit a ticking time bomb for Premier League clubs and European stars',
#  'Brexit talks "closing in on workable solutions", Raab says',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Johnson’s Brexit suicide-belt remarks ‘disgusting’',
#  "Brexit: 150-plus countries yet to agree to 'rollover' existing deals on trade, flights and nuclear safety",
#  'Pro-Brexit group predicts UK boom after EU departure',
#  'Brexit leaves UK lost in space amid possible EU Galileo space project exclusion',
#  'Wrong Brexit will cost tens of thousands of car jobs, warns Jaguar boss',
#  'Boris Johnson against Brexit plan, not May',
#  'Labour to vote AGAINST Brexit deal signals Emily Thornberry in major blow for Theresa May',
#  'Brexit divorce bill: this is how much we could have to pay to leave the EU and why',
#  'London Fashion Week kicks off amid Brexit woes',
#  'France says British planes and Eurostar trains would be turned away from Europe under a no-deal Brexit',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Special summit to sign Brexit deal expected in November',
#  'People and power before and after Brexit',
#  'Retailers feel pinch in Brexit-backing Darlington',
#  'Brexit no-deal papers: The key things we’ve learned from the latest release',
#  "Boris Johnson's Brexit 'suicide vest' comment sparks furore",
#  'Leader comment: Tories may lose Brexit blame game',
#  'London Mayor Sadiq Khan calls for SECOND Brexit vote to give UK chance of staying in EU',
#  'Theresa May Calls for Meeting to Discuss ‘No Deal’ Scenario on Brexit',
#  'London Mayor Adds to Pressure on Corbyn to Back New Brexit Vote',
#  'Ten years after the financial crisis, the UK is facing another huge economic shock in the form of Brexit – th…',
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Labour warns it will reject ‘blind Brexit’ deal',
#  "Theresa May's Brexit plans 'opposed by 80 rebels in her party'",
#  "Manchester Airport boss urges region's businesses to plan for no-deal Brexit",
#  "Boris Johnson compares latest Brexit deal to a 'suicide vest'",
#  'Brexit loan scheme pays out €2.5m to Irish firms',
#  'Theresa May should sort Brexit deal and then go, former policy chief says',
#  'Tory Kafuffles: Boris Johnson, Brexit and Suicide Vests',
#  'Johnson says supports May, opposes her Brexit plan - newspaper',
#  'Brexit news: tells rivals ‘FOCUS ON BREXIT’ and LASHES OUT at ‘inappropriate’ Johnson | Politics | News – UK',
#  "Newspaper headlines: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  'Bafta chief says UK entertainment industry will ‘thrive’ post-Brexit',
#  "The Papers: 'Brexit vote needed' and Ruth Davidson's teenage self-harm",
#  'Boris Johnson’s Brexit jibe puts Theresa May on notice',
#  'Brexit: EU squashes hopes of Ireland breakthrough in Salzburg',
#  'Brexit minister Raab: No EU deal, no settlement',
#  'MPs call for ban on Irish fishing vessels after Brexit',
#  'London mayor Sadiq Khan calls for second Brexit referendum – UK',
#  'British companies excluded from EU Galileo space project if no-deal Brexit',
#  'MIL-OSI United Kingdom: Mayor of London calls for public vote on Brexit',
#  'Will Britain pay £39bn Brexit ‘bill’?',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "Blame Brexit: New York becomes world's top financial centre",
#  "The EU says a Brexit deal with the UK is 'realistic' within 6 to 8 weeks",
#  'Look out EU! Theresa May warns EU she is still a ‘bloody difficult woman’ over Brexit',
#  'Deep divisions in British politics with just 200 days to Brexit',
#  "Boris Johnson's 'suicide vest' jibe to May sparks new Brexit row",
#  'Lib Dems call for remainer ministers to back vote on Brexit terms',
#  'Blair calls on EU to step in and help Brexit impasse',
#  '‘We NEED a people’s vote’ – London Mayor Sadiq Khan requires SECOND Brexit referendum',
#  'BBC reporter claims Lib Dems are the only anti-Brexit party in UK',
#  'Government reveals automotive guidance for no-deal Brexit',
#  "No alternative to May's Brexit plan: govt",
#  'Theresa May must not get caught in a Von Trapp at the EU summit in Salzburg to make Brexit a success',
#  'Put London’s place as the capital of fashion at the heart of Brexit talks',
#  "Britain to publish more 'no deal' Brexit advice papers",
#  'Brexit is what we voted for',
#  'Morning Market Pulse - Brexit Carney-age for UK house prices?',
#  'UK.gov finally adds Galileo and Copernicus to the Brexit divorce bill',
#  'UK will extend GSP+ incentives to Pakistan post Brexit: envoy',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  "No alternative to May's Brexit plan: govt",
#  'Theresa May must not get caught in a Von Trapp at the EU summit in Salzburg to make Brexit a success',
#  'Put London’s place as the capital of fashion at the heart of Brexit talks',
#  "Britain to publish more 'no deal' Brexit advice papers",
#  'Brexit is what we voted for',
#  'Morning Market Pulse - Brexit Carney-age for UK house prices?',
#  'UK.gov finally adds Galileo and Copernicus to the Brexit divorce bill',
#  'UK will extend GSP+ incentives to Pakistan post Brexit: envoy',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  "No alternative to May's Brexit plan: govt",
#  'Theresa May must not get caught in a Von Trapp at the EU summit in Salzburg to make Brexit a success',
#  'Put London’s place as the capital of fashion at the heart of Brexit talks',
#  "Britain to publish more 'no deal' Brexit advice papers",
#  'Brexit is what we voted for',
#  'Morning Market Pulse - Brexit Carney-age for UK house prices?',
#  'UK.gov finally adds Galileo and Copernicus to the Brexit divorce bill',
#  'UK will extend GSP+ incentives to Pakistan post Brexit: envoy',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  "No alternative to May's Brexit plan: govt",
#  'Theresa May must not get caught in a Von Trapp at the EU summit in Salzburg to make Brexit a success',
#  'Put London’s place as the capital of fashion at the heart of Brexit talks',
#  "Britain to publish more 'no deal' Brexit advice papers",
#  'Brexit is what we voted for',
#  'Morning Market Pulse - Brexit Carney-age for UK house prices?',
#  'UK.gov finally adds Galileo and Copernicus to the Brexit divorce bill',
#  'UK will extend GSP+ incentives to Pakistan post Brexit: envoy',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  "No alternative to May's Brexit plan: govt",
#  'Theresa May must not get caught in a Von Trapp at the EU summit in Salzburg to make Brexit a success',
#  'Put London’s place as the capital of fashion at the heart of Brexit talks',
#  "Britain to publish more 'no deal' Brexit advice papers",
#  'Brexit is what we voted for',
#  'Morning Market Pulse - Brexit Carney-age for UK house prices?',
#  'UK.gov finally adds Galileo and Copernicus to the Brexit divorce bill',
#  'UK will extend GSP+ incentives to Pakistan post Brexit: envoy',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  "No alternative to May's Brexit plan: govt",
#  'Theresa May must not get caught in a Von Trapp at the EU summit in Salzburg to make Brexit a success',
#  'Put London’s place as the capital of fashion at the heart of Brexit talks',
#  "Britain to publish more 'no deal' Brexit advice papers",
#  'Brexit is what we voted for',
#  'Morning Market Pulse - Brexit Carney-age for UK house prices?',
#  'UK.gov finally adds Galileo and Copernicus to the Brexit divorce bill',
#  'UK will extend GSP+ incentives to Pakistan post Brexit: envoy',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  "No alternative to May's Brexit plan: govt",
#  'Theresa May must not get caught in a Von Trapp at the EU summit in Salzburg to make Brexit a success',
#  'Put London’s place as the capital of fashion at the heart of Brexit talks',
#  "Britain to publish more 'no deal' Brexit advice papers",
#  'Brexit is what we voted for',
#  'Morning Market Pulse - Brexit Carney-age for UK house prices?',
# ...
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  "Bank of England's Carney to stay seven months longer to help Brexit",
#  'Of Felipe Gonzalez, Spanish bullrings and Brexit',
#  'EU Exchanges Warned To Apply To FCA Before Brexit',
#  "Chatting about the 'misinformation and misleading information' of Brexit",
#  'Preparing for a No Deal Brexit',
#  ...]
